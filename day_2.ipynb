# %%
import pandas as pd

# %%
url='https://tinyurl.com/titanic-csv'

# %%
dataframe=pd.read_csv(url)

# %%
print(dataframe)
# Out:
#                                                   Name PClass    Age     Sex  \
# 0                         Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                          Allison, Miss Helen Loraine    1st   2.00  female
# 2                  Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3        Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                        Allison, Master Hudson Trevor    1st   0.92    male
# 5                                   Anderson, Mr Harry    1st  47.00    male
# 6                     Andrews, Miss Kornelia Theodosia    1st  63.00  female
# 7                               Andrews, Mr Thomas, jr    1st  39.00    male
# 8         Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.00  female
# 9                               Artagaveytia, Mr Ramon    1st  71.00    male
# 10                           Astor, Colonel John Jacob    1st  47.00    male
# ...

# %%
dataframe.replace(1,"one", inplace=True)

# %%
dataframe.replace(0,"zero", inplace=True)

# %%
print(dataframe)
# Out:
#                                                   Name PClass   Age     Sex  \
# 0                         Allen, Miss Elisabeth Walton    1st    29  female
# 1                          Allison, Miss Helen Loraine    1st     2  female
# 2                  Allison, Mr Hudson Joshua Creighton    1st    30    male
# 3        Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st    25  female
# 4                        Allison, Master Hudson Trevor    1st  0.92    male
# 5                                   Anderson, Mr Harry    1st    47    male
# 6                     Andrews, Miss Kornelia Theodosia    1st    63  female
# 7                               Andrews, Mr Thomas, jr    1st    39    male
# 8         Appleton, Mrs Edward Dale (Charlotte Lamson)    1st    58  female
# 9                               Artagaveytia, Mr Ramon    1st    71    male
# 10                           Astor, Colonel John Jacob    1st    47    male
# ...

# %%
dataframe.rename(columns={'PClass':'passenger name'}).head(2)
# Out:
#                            Name passenger name Age     Sex Survived SexCode
# 0  Allen, Miss Elisabeth Walton            1st  29  female      one     one
# 1   Allison, Miss Helen Loraine            1st   2  female     zero     one

# %%
print(dataframe)
# Out:
#                                                   Name PClass   Age     Sex  \
# 0                         Allen, Miss Elisabeth Walton    1st    29  female
# 1                          Allison, Miss Helen Loraine    1st     2  female
# 2                  Allison, Mr Hudson Joshua Creighton    1st    30    male
# 3        Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st    25  female
# 4                        Allison, Master Hudson Trevor    1st  0.92    male
# 5                                   Anderson, Mr Harry    1st    47    male
# 6                     Andrews, Miss Kornelia Theodosia    1st    63  female
# 7                               Andrews, Mr Thomas, jr    1st    39    male
# 8         Appleton, Mrs Edward Dale (Charlotte Lamson)    1st    58  female
# 9                               Artagaveytia, Mr Ramon    1st    71    male
# 10                           Astor, Colonel John Jacob    1st    47    male
# ...
